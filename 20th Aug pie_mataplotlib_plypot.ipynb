# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mileage = sns.load_dataset('mpg')
mileage.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
avg_mpg = mileage.groupby(by = 'cylinders')[['mpg','cylinders']].mean()
avg_mpg
# Out:
#                  mpg  cylinders
# cylinders
# 3          20.550000        3.0
# 4          29.286765        4.0
# 5          27.366667        5.0
# 6          19.985714        6.0
# 8          14.963107        8.0

# %%
#Pie
plt.pie(x=avg_mpg['mpg'],labels=avg_mpg['cylinders'])
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.pie(x=avg_mpg['mpg'],labels=avg_mpg['cylinders'],explode=[0,0,0,0.05,0.3], autopct = '%.2f')
plt.title('avg_miles_per_Cylinder_type')
plt.show()

# %% [markdown]
# #Another example

# %%
rupees_monthly = [2000, 2530, 900, 15000, 1500]
items = ['Tution_fee','Mobile_bill','Electricity_bill','Rent','Misc']

df=pd.DataFrame({'Expenses':rupees_monthly,'items':items})
df
# Out:
#    Expenses             items
# 0      2000        Tution_fee
# 1      2530       Mobile_bill
# 2       900  Electricity_bill
# 3     15000              Rent
# 4      1500              Misc

# %%
plt.figure(figsize=(8,8))
plt.pie(x=df['Expenses'],labels=df['items'],explode=(0,0,0,0.05,0.3), autopct = '%.1f',rotatelabels=True)
plt.show()
